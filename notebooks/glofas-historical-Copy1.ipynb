# %%
import climetlab as cml

# %%
gl_historical = cml.load_dataset(
            'cems-flood-glofas-historical',
            model='lisflood',
            product_type='consolidated',
            system_version='version_3_1',
            period='20210101-20210131',
            variable="river_discharge_in_the_last_24_hours"
        )
# Out:
# By downloading data from this dataset, you agree to the terms and conditions defined at https://github.com/ecmwf-lab/climetlab_cems_flood/LICENSEIf you do not agree with such terms, do not download the data.

# %%
ds = gl_historical.to_xarray()
# Out:
# 2022-02-10 09:55:35,007 WARNING Ignoring index file '/tmp/climetlab-iff/c-dsretriever-62edd7f678e7242d4907b9a00d3e5b88f96ae672b3e6ff455853e452bd4d4dcf.grib.923a8.idx' incompatible with GRIB file

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:    (time: 31, latitude: 1500, longitude: 3600)
# Coordinates:
#   * time       (time) datetime64[ns] 2021-01-01 2021-01-02 ... 2021-01-31
#   * latitude   (latitude) float64 89.95 89.85 89.75 ... -59.75 -59.85 -59.95
#   * longitude  (longitude) float64 -179.9 -179.8 -179.8 ... 179.7 179.8 179.9
# Data variables:
#     dis24      (time, latitude, longitude) float32 dask.array<chunksize=(31, 1500, 3600), meta=np.ndarray>
# Attributes:
#     GRIB_edition:            2
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             European Centre for Medium-Range Weather Forecasts
#     history:                 2022-02-10T09:55 GRIB to CDM+CF via cfgrib-0.9.1...

# %%
gl_historical_ts = cml.load_dataset(
            'cems-flood-glofas-historical',
            model='lisflood',
            product_type='consolidated',
            system_version='version_3_1',
            period='20210101-20210331',
            variable="river_discharge_in_the_last_24_hours",
            lat = 51.35,
            lon = -0.45
)

# %%
gl_historical_ts_2 = cml.load_dataset(
            'cems-flood-glofas-historical',
            model='lisflood',
            product_type='consolidated',
            system_version='version_3_1',
            period='*0101-*0331',
            variable="river_discharge_in_the_last_24_hours",
            lat = 51.35,
            lon = -0.45
)
# Out:
# ---------------------------------------------------------------------------
# StringNotValidError                       Traceback (most recent call last)
# Input In [11], in <module>
# ----> 1 gl_historical_ts_2 = cml.load_dataset(
#       2             'cems-flood-glofas-historical',
#       3             model='lisflood',
#       4             product_type='consolidated',
#       5             system_version='version_3_1',
#       6             period='*0101-*0331',
#       7             variable="river_discharge_in_the_last_24_hours",
#       8             lat = 51.35,
#       9             lon = -0.45
#      10 )
#
# File ~/.pyenv/versions/cems-flood/lib/python3.9/site-packages/climetlab/datasets/__init__.py:258, in load_dataset(name, *args, **kwargs)
#     255         print(klass.terms_of_use)
#     256     TERMS_OF_USE_SHOWN.add(name)
# --> 258 ds = klass(*args, **kwargs).mutate()
#     259 if getattr(ds, "name", None) is None:
#     260     ds.name = name
#
# File ~/.pyenv/versions/cems-flood/lib/python3.9/site-packages/climetlab/core/__init__.py:17, in MetaBase.__call__(cls, *args, **kwargs)
#      15 obj = cls.__new__(cls, *args, **kwargs)
#      16 args, kwargs = cls.patch(obj, *args, **kwargs)
# ---> 17 obj.__init__(*args, **kwargs)
#      18 return obj
#
# File ~/development/climetlab-cems-flood/climetlab_cems_flood/glofas_historical.py:41, in GlofasHistorical.__init__(self, system_version, product_type, model, variable, period, area, lat, lon, split_on)
#      37 def __init__(self, system_version, product_type, model, variable, period, area = None, lat = None, lon = None, split_on =None):
#      39     self.parser = Parser(self.temporal_range)
# ---> 41     years, months, days = self.parser.period(period)
#      43     months = months_num2str(months)
#      45     if lat is not None and lon is not None:
#
# File ~/development/climetlab-cems-flood/climetlab_cems_flood/utils.py:72, in Parser.period(cls, string)
#      60 @classmethod
#      61 def period(cls,string):
#      63     PATTERN = {"[0-9]{8}":{}, # most frequent
#      64             "\*[0-9]{2}[0-9]{2}":[cls.Y,string[1:3],string[3:]],
#      65             "[0-9]{4}\*[0-9]{2}":[string[:4],M,string[5:]],
#    (...)
#      69             "\*\*[0-9]{2}":[cls.Y,M,string[3:]],
#      70             "\*\*\*":[cls.Y,M,D]}
# ---> 72     _validate(string)
#      74     if "*" in string:
#      75         years = set()
#
# File ~/development/climetlab-cems-flood/climetlab_cems_flood/utils.py:116, in _validate(string)
#     114 def _validate(string):
#     115     if ("*" in string and "-" in string) or ("*" in string and "/" in string):
# --> 116         raise StringNotValidError(string," '*' and '-' or '*' and '/' are not allowed in the same string")
#     117     else:
#     118         pass
#
# StringNotValidError: ('*0101-*0331', " '*' and '-' or '*' and '/' are not allowed in the same string")

# %%
d2021 = gl_historical_ts.to_xarray()
d2020 = gl_historical_ts_2.to_xarray()
# Out:
# 2022-02-10 09:56:53,471 WARNING Ignoring index file '/tmp/climetlab-iff/c-dsretriever-682a78f1a3487be7bbb9129768643daf14e66479bbd6b13dd4ad8c00ac46bcf6.grib.923a8.idx' incompatible with GRIB file

# %%
d2021.dis24[:,0,0].plot()
d2020.dis24[:,0,0].plot()
